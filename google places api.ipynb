# %%
api_key = "AIzaSyBDFpM-MaaV-IgoBJBgL1e9tAgumymusjc"

# %%
import requests
from urllib.parse import urlencode

# %%
lat = 39.168553
lng = -86.533470

# %%
base_endpoint_places = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
params = {
    "key": api_key,
    "input": "Mexican food",
    "inputtype": "textquery",
    "fields": "place_id,formatted_address,name,geometry,permanently_closed"
}
locationbias = f"point:{lat},{lng}"
use_cirular = True
if use_cirular:
    radius = 5000
    locationbias = f"circle:{radius}@{lat},{lng}"

params['locationbias'] = locationbias

params_encoded = urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyBDFpM-MaaV-IgoBJBgL1e9tAgumymusjc&input=Mexican+food&inputtype=textquery&fields=place_id%2Cformatted_address%2Cname%2Cgeometry%2Cpermanently_closed&locationbias=circle%3A5000%4037.42230960000001%2C-122.0846244

# %%
places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_2 = {
    "key": api_key,
    "location": f"{lat},{lng}",
    "radius": 1500,
    "keyword": "fast food"
}
params_2_encoded = urlencode(params_2)
places_url = f"{places_endpoint_2}?{params_2_encoded}"

r2 = requests.get(places_url)

# %%
r2.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1595449, 'lng': -86.5341152},
#     'viewport': {'northeast': {'lat': 39.16089447989272,
#       'lng': -86.53274442010728},
#      'southwest': {'lat': 39.15819482010728, 'lng': -86.53544407989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Rally's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100328146708358406871">Rally&#39;s</a>'],
#      'photo_reference': 'AcYSjRjxKWfELj4H7nok-6bf-yQFqx9Nav2Y33Cmiruwwbx6EJCKfGPJ_Mqw2bl1EV9DgBFb7x-Tp4YnIANWF8QWo5dWboqP99Jx2n40yFFm4fCz8Ipfx3EawyEA5Kdz_azOuptaM0p9KJvT2TdQqRDiFeSkFHljYaQo0kg7otuL2kFmLA4W',
#      'width': 1440}],
#    'place_id': 'ChIJi8WMIeRmbIgR-5qohDUhCog',
#    'plus_code': {'compound_code': '5F58+R9 Bloomington, Indiana',
#     'global_code': '86FM5F58+R9'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJi8WMIeRmbIgR-5qohDUhCog',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1034,
#    'vicinity': '550 S Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1689804, 'lng': -86.53403139999999},
#     'viewport': {'northeast': {'lat': 39.17026977989271,
#       'lng': -86.53265202010728},
#      'southwest': {'lat': 39.16757012010727, 'lng': -86.53535167989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Taco Bell',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100418446568341950728">Taco Bell</a>'],
#      'photo_reference': 'AcYSjRhj7kYJxzf0F_NEB9g5AXCOk_PIgaigBUBxx5iSomBssevr4EkGCSw98RJmC7pJt7lPuzCMGUXf7ZwDT9Fo1xepNAgAz_it7qcO5CZv9mxSUcjvmAgrLwXn0Iq9RQpPzwD3bz7hLDPPvZmoziyGkOJyw11G62nO7ZDLSR_138SqjGqa',
#      'width': 600}],
#    'place_id': 'ChIJCysUR9xmbIgR-6gDsICRwO4',
#    'plus_code': {'compound_code': '5F98+H9 Bloomington, Indiana',
#     'global_code': '86FM5F98+H9'},
#    'price_level': 1,
#    'rating': 3.3,
#    'reference': 'ChIJCysUR9xmbIgR-6gDsICRwO4',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 765,
#    'vicinity': '309 N Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1611023, 'lng': -86.535764},
#     'viewport': {'northeast': {'lat': 39.16249337989272,
#       'lng': -86.53446422010727},
#      'southwest': {'lat': 39.15979372010727, 'lng': -86.5371638798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Wendy's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111714396178288168178">Wendy&#39;s</a>'],
#      'photo_reference': 'AcYSjRhiJTHA60X3eDdUHxIWlpn71rUbTaUQ1igKKIQGRpa75Nbr6_-ibV7pqmepuCaqak1q5sPD9gl_iuDA6285yFzvHbbpcBdJorDtEuFh7gBZszPw33tBKQ116zuWVz3gk_eXoIRXghl6UlvhrPHbR2qK36FiVmIn2bGD8XMMi_56lKSW',
#      'width': 720}],
#    'place_id': 'ChIJp0mrS-FmbIgRoxS6RrUXhVQ',
#    'plus_code': {'compound_code': '5F67+CM Bloomington, Indiana',
#     'global_code': '86FM5F67+CM'},
#    'price_level': 1,
#    'rating': 3.9,
#    'reference': 'ChIJp0mrS-FmbIgRoxS6RrUXhVQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 828,
#    'vicinity': '221 W 2nd St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1666851, 'lng': -86.5286156},
#     'viewport': {'northeast': {'lat': 39.16799962989272,
#       'lng': -86.52726652010726},
#      'southwest': {'lat': 39.16529997010728, 'lng': -86.52996617989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Five Guys',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107434773794879129936">A Google User</a>'],
#      'photo_reference': 'AcYSjRjGsCulKBDWCi7Cl8Mez6H_v4satfVJiw0BOz9NJDGU7XdZzrIGvWOGOP7NF-etc9_0BEbPE5kxrh0pafrA88TsxL_yS7dLiEU0O9T4SO5EreiXKHj4cwfjPid8kBOS294ezayiZ0P6i4tRzcyDbKE-VTESWvZo0Zze3kqz4xg6plqr',
#      'width': 4032}],
#    'place_id': 'ChIJRXyDRNpnbIgRQs5YClpXTNw',
#    'plus_code': {'compound_code': '5F8C+PH Bloomington, Indiana',
#     'global_code': '86FM5F8C+PH'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJRXyDRNpnbIgRQs5YClpXTNw',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 197,
#    'vicinity': '425 E Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1654941, 'lng': -86.5506126},
#     'viewport': {'northeast': {'lat': 39.16676247989272,
#       'lng': -86.54911732010729},
#      'southwest': {'lat': 39.16406282010728, 'lng': -86.55181697989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Hinkle's Hamburgers",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107502112192510499235">John Kendall II</a>'],
#      'photo_reference': 'AcYSjRiFC19m0jxrBZRUNDuynBlJSKMJWLHTnBeSdqeuckxi__bWbzH9nE3ss7w_m6tV8I_bw1ljPHKnHuAeJdiWE6IS3mdtlNaV2Ey_v6lVlWbcxnKErrujrcNCT-C4ITXoRHhn34JJ74F4RKn33Gge3f3sn4iKvh3s-Jk_OBhVKsDdvylE',
#      'width': 1920}],
#    'place_id': 'ChIJu-YruRdnbIgRBBsNsPkwdmo',
#    'plus_code': {'compound_code': '5C8X+5P Bloomington, Indiana',
#     'global_code': '86FM5C8X+5P'},
#    'price_level': 1,
#    'rating': 4.6,
#    'reference': 'ChIJu-YruRdnbIgRBBsNsPkwdmo',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 673,
#    'vicinity': '206 S Adams St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1600089, 'lng': -86.5333782},
#     'viewport': {'northeast': {'lat': 39.16136092989272,
#       'lng': -86.53212237010729},
#      'southwest': {'lat': 39.15866127010728, 'lng': -86.53482202989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Arby's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 583,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113732087908308988637">Arby&#39;s</a>'],
#      'photo_reference': 'AcYSjRhEuxTxnSDLKprJdq1_dp6DD-w5vo-6W3D4QmB2H1qywcviE8rL4pFMVDy1-ud1e5jYpZnjFT8BUopaS2S9ZxBTbAkfI0xQOyHayDDZ7UOW2_YKXJPmP32UPmJGqiVR2O_lLKXH3JHdPCo9xXlnDLzQAocZiWcIMi3-AdC-WMgl6fwN',
#      'width': 1114}],
#    'place_id': 'ChIJocv9JuRmbIgRv_zjdhxboNE',
#    'plus_code': {'compound_code': '5F68+2M Bloomington, Indiana',
#     'global_code': '86FM5F68+2M'},
#    'price_level': 1,
#    'rating': 3.9,
#    'reference': 'ChIJocv9JuRmbIgRv_zjdhxboNE',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 400,
#    'vicinity': '535 S Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.166235, 'lng': -86.52850740000001},
#     'viewport': {'northeast': {'lat': 39.16774067989272,
#       'lng': -86.52711222010727},
#      'southwest': {'lat': 39.16504102010727, 'lng': -86.52981187989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Jimmy John's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110752253781370465508">Marc Abplanalp</a>'],
#      'photo_reference': 'AcYSjRi46moWCNWKv10ZlALCxtiDAd2Z40D08wHLsSEq2lQjMNTFKYQQT1XGKs8KLJJ2iX6NlpbAnfFKsvhXHEptqaERO3S-iabK3dUhps8IXGEineMCGF_b_G5k9Yiv4MbhU64sNPZR0Dl7wroi8fO0Ba-sm7l6X8zh2G6y1ARnHfsOJih8',
#      'width': 1080}],
#    'place_id': 'ChIJYcKwlMJmbIgRYr6LY-zNcy4',
#    'plus_code': {'compound_code': '5F8C+FH Bloomington, Indiana',
#     'global_code': '86FM5F8C+FH'},
#    'price_level': 1,
#    'rating': 3.5,
#    'reference': 'ChIJYcKwlMJmbIgRYr6LY-zNcy4',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 121,
#    'vicinity': '430 E Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1662505, 'lng': -86.5288217},
#     'viewport': {'northeast': {'lat': 39.16774892989272,
#       'lng': -86.52747122010727},
#      'southwest': {'lat': 39.16504927010727, 'lng': -86.53017087989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Raising Cane's Chicken Fingers",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1500,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102973141689689491832">A Google User</a>'],
#      'photo_reference': 'AcYSjRj2FCYAlKGcwkZYPgGtj0q3GtRptyXP5wPH7PC63I0T7P9ZeaBy8ZQsN2__sh0NGYEig8QPQ1BdCPEuVZxxDKKs4FDeFrTWb9ZwATjgmShvU1-ufSj1v42H1sDQ8RZ6van-b3h8hk9tCU62eT2JNh20GQVgaVdnbtUhs6s9QNYY6Rb8',
#      'width': 1500}],
#    'place_id': 'ChIJF9HqlpdnbIgRLYto2yJ-g1k',
#    'plus_code': {'compound_code': '5F8C+GF Bloomington, Indiana',
#     'global_code': '86FM5F8C+GF'},
#    'price_level': 1,
#    'rating': 3.3,
#    'reference': 'ChIJF9HqlpdnbIgRLYto2yJ-g1k',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 39,
#    'vicinity': '422 E Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.165704, 'lng': -86.52709899999999},
#     'viewport': {'northeast': {'lat': 39.16697312989272,
#       'lng': -86.52576507010727},
#      'southwest': {'lat': 39.16427347010728, 'lng': -86.52846472989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'QDOBA Mexican Eats',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 5000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115478436263947727833">Qdoba Mexican Grill</a>'],
#      'photo_reference': 'AcYSjRgt5pyqw53-ljVnTCj-yKo354syXkminU1y_DeCBc3lOQE-KGdzmCFUKEheSwR1MQBj3hodX-v0Xel1FlUOFiD7v0iqiXj4MC_xdub_P_ZqlqDrE2WlBnN27kMSOIpj4qUjFcKhKvLRCDHAzGx4tm0A6xZTCRoSUkwZHkPr5kqLm8Kk',
#      'width': 5000}],
#    'place_id': 'ChIJr6mkZ8JmbIgRnDKxAWikkPw',
#    'plus_code': {'compound_code': '5F8F+75 Bloomington, Indiana',
#     'global_code': '86FM5F8F+75'},
#    'price_level': 1,
#    'rating': 4.4,
#    'reference': 'ChIJr6mkZ8JmbIgRnDKxAWikkPw',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 300,
#    'vicinity': '116 S Indiana Ave Suite 200, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1662857, 'lng': -86.52904219999999},
#     'viewport': {'northeast': {'lat': 39.16769057989272,
#       'lng': -86.52773297010727},
#      'southwest': {'lat': 39.16499092010727, 'lng': -86.53043262989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Chipotle Mexican Grill',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100889920549088365838">Anirudh Pillai</a>'],
#      'photo_reference': 'AcYSjRgdRE4VQ91T4bbYdjZjyzQg7kPha2neXFNBE4psZ-9zv1v_vbS5lmlQmmLZrPvOcsLQr4ccSudMWf2PNCBY2ZqIWHQk08Emlw4fCQxdnTnmhDRnlZFSpBWB-JFjh0NQi3uBGR2TQgO6D1ARrwPWgXbKZRLhmgOfI1Az08qKFbYoSNA',
#      'width': 1920}],
#    'place_id': 'ChIJezXRt8JmbIgRx8hhzxhAgms',
#    'plus_code': {'compound_code': '5F8C+G9 Bloomington, Indiana',
#     'global_code': '86FM5F8C+G9'},
#    'price_level': 1,
#    'rating': 3.8,
#    'reference': 'ChIJezXRt8JmbIgRx8hhzxhAgms',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 539,
#    'vicinity': '420 E Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1667031, 'lng': -86.5275841},
#     'viewport': {'northeast': {'lat': 39.16797442989272,
#       'lng': -86.52626847010728},
#      'southwest': {'lat': 39.16527477010727, 'lng': -86.52896812989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Potbelly',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 900,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108470015569434102985">Potbelly Sandwich Shop</a>'],
#      'photo_reference': 'AcYSjRiCew57hRRPK3dGJYrcd8gIJbRfItOcEmzvVL965FtqHWQ5gvrQt8C3LWUepKi5w63zyg4SJuorqqpYGhMDWy-EZgiEN1nt5nPo3EbhZ7YrrVQQdwBhwg6-bu1pLkfiEyMsW4l99xhv1sbVT2VNgbNEQA5go_7ui1R5Z7L1EvqFHuyI',
#      'width': 1600}],
#    'place_id': 'ChIJ97ej9cJmbIgRLOQGfM8QaWg',
#    'plus_code': {'compound_code': '5F8C+MX Bloomington, Indiana',
#     'global_code': '86FM5F8C+MX'},
#    'price_level': 1,
#    'rating': 4.4,
#    'reference': 'ChIJ97ej9cJmbIgRLOQGfM8QaWg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 123,
#    'vicinity': '517 E Kirkwood Ave, Bloomington'}],
#  'status': 'OK'}

# %%
df = r2.json()['results']

# %%
import pandas as pd

# %%
 data = pd.DataFrame(df)

# %%
places_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyBDFpM-MaaV-IgoBJBgL1e9tAgumymusjc&location=39.168553%2C-86.53347&radius=1500&keyword=Mexican+food'

# %%
places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_2 = {
    "key": api_key,
    "location": f"{lat},{lng}",
    "radius": 1500,
    "keyword": "Mexican food"
}
params_2_encoded = urlencode(params_2)
places_url = f"{places_endpoint_2}?{params_2_encoded}"

r3 = requests.get(places_url)

# %%
r3.json()
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1674315, 'lng': -86.53503049999999},
#     'viewport': {'northeast': {'lat': 39.16884892989272,
#       'lng': -86.53367207010727},
#      'southwest': {'lat': 39.16614927010727, 'lng': -86.53637172989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Social Cantina',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3072,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101872697305009838157">Mariella Arredondo</a>'],
#      'photo_reference': 'AcYSjRjeEuCP1QPoqghz8DAayKviEXro0vAq8xBI2NF5gv-_RcjmlBxiv7WfC9h30GwZ7gdwbzrqCHYVzh-h93EULACtcPJk5jZfIWHf_8lgftMjyjTledK_wGyBLXj4uwZrR_E2hVSSC913N8XLaCy8sBrZWzIVpp8jyg7pGy8Nlw27O-F3',
#      'width': 4096}],
#    'place_id': 'ChIJBQDQed5mbIgRt08KWIRAFmY',
#    'plus_code': {'compound_code': '5F87+XX Bloomington, Indiana',
#     'global_code': '86FM5F87+XX'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJBQDQed5mbIgRt08KWIRAFmY',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 896,
#    'vicinity': '125 N College Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1668263, 'lng': -86.5406788},
#     'viewport': {'northeast': {'lat': 39.16814467989272,
#       'lng': -86.53944142010727},
#      'southwest': {'lat': 39.16544502010727, 'lng': -86.54214107989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Juannita's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4923,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107733853769075629218">A Google User</a>'],
#      'photo_reference': 'AcYSjRgjJtLMYw3QCK9pxQSUMc3geBMeJlkAXijVl8whTe2iQEJDObVvkT0VewpAGEVS7booGN2ubFn11ZUaAtDq8uTGZNZoWFk8POJVdP2MrcoktscNOlRXnvfj3Cm3zWg-cSIb_qqorxUcQx6hUBOVIBPb_9diJws-sUq68_QVI4lXhx49',
#      'width': 7400}],
#    'place_id': 'ChIJVVVoDSBnbIgRvHC11cM2MSA',
#    'plus_code': {'compound_code': '5F85+PP Bloomington, Indiana',
#     'global_code': '86FM5F85+PP'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJVVVoDSBnbIgRvHC11cM2MSA',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 719,
#    'vicinity': '620 W Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1718403, 'lng': -86.53525429999999},
#     'viewport': {'northeast': {'lat': 39.17328227989273,
#       'lng': -86.53367922010726},
#      'southwest': {'lat': 39.17058262010729, 'lng': -86.53637887989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "The 3 Amigos B'Town",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1236,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114853924809812099076">salome espinosa</a>'],
#      'photo_reference': 'AcYSjRhfzCY1nSnRc_cNmG_fBmw4ZIOI3dgnEtbwax4iV8mOzYmrelgZGoEDbDWB5uOlyA2kT5agmv32Hc1lVDAD72Y1QAVaPqar8C_JoLeLU6AlnMq3QH-UXS_0mLUGLJUs12XLtG60NW_MeOy5y0Ola8iSXwWh3asBIQA9BDQvLQl53byY',
#      'width': 2543}],
#    'place_id': 'ChIJuWoUz_FnbIgRGgCOaAYqUGs',
#    'plus_code': {'compound_code': '5FC7+PV Bloomington, Indiana',
#     'global_code': '86FM5FC7+PV'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJuWoUz_FnbIgRGgCOaAYqUGs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 367,
#    'vicinity': '601 N College Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1661473, 'lng': -86.5334147},
#     'viewport': {'northeast': {'lat': 39.16749707989273,
#       'lng': -86.53216217010727},
#      'southwest': {'lat': 39.16479742010728, 'lng': -86.53486182989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Pili's Party Deli",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105747007475629455747">허성욱</a>'],
#      'photo_reference': 'AcYSjRiwGSfVm8q5BLMIMDdKGXaaSEvDGQjtE97o_P2HQtk3T6NGyoFKhn2sdk9MkbdZUEdylZl6LDjCwrTiGIzft2rdf3IPiX8034eII3_Zc64nPeyd93legx_cfge9nJ-9otzrVScAfIRdGPAso8fznLZyD6cW9mF42pIgkqibQE4M9x6z',
#      'width': 4032}],
#    'place_id': 'ChIJk8drlRxnbIgRfP6LX4AcHPE',
#    'plus_code': {'compound_code': '5F88+FJ Bloomington, Indiana',
#     'global_code': '86FM5F88+FJ'},
#    'rating': 4.5,
#    'reference': 'ChIJk8drlRxnbIgRfP6LX4AcHPE',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'grocery_or_supermarket',
#     'store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': '109 S Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1684178, 'lng': -86.53342699999999},
#     'viewport': {'northeast': {'lat': 39.16977912989272,
#       'lng': -86.53215222010728},
#      'southwest': {'lat': 39.16707947010728, 'lng': -86.53485187989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'La Una Cantina',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111609152896398373622">A Google User</a>'],
#      'photo_reference': 'AcYSjRjqKfrXKh07r4iQhhIUHGsRCj2f5EKwqW-xYJFE3Kfer-HzVfV3oWphU3kKbT7sqr4iKaGbXrWmaGx6IiG82Kv4Hk_o0w5r9kQiIoyZvwKn5hOV8alP7aIdacaOfFFpoOk9Dvb2s1pM_V9H7VSRjXQ-zmkiWlxt0-cYiLfRxHtnGdYv',
#      'width': 683}],
#    'place_id': 'ChIJ7VonFx9nbIgRknGuWgbsNt0',
#    'plus_code': {'compound_code': '5F98+9J Bloomington, Indiana',
#     'global_code': '86FM5F98+9J'},
#    'rating': 4.1,
#    'reference': 'ChIJ7VonFx9nbIgRknGuWgbsNt0',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 245,
#    'vicinity': '254 N Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.182553, 'lng': -86.53357299999999},
#     'viewport': {'northeast': {'lat': 39.18387097989272,
#       'lng': -86.53232827010727},
#      'southwest': {'lat': 39.18117132010727, 'lng': -86.53502792989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'La Charreada',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103534274528302525705">A Google User</a>'],
#      'photo_reference': 'AcYSjRj-nIgwCmuRJqxOawfuoV899nV_hB62I8fgG3J9-0ySmmXIHN4Z7w69EakE-4iD8lOnrqEr-nlhnMW0jeCKB4doqPDPdAApZIS9kCCF4_QcxcjiLcme9dCWILhrT_YJSbfiz-2z8oKudbmSbCK3l4zNYdgptqsi277Ac6dQr7LIIMmY',
#      'width': 4032}],
#    'place_id': 'ChIJIdd9mdNmbIgR0jZqHfrikTc',
#    'plus_code': {'compound_code': '5FM8+2H Bloomington, Indiana',
#     'global_code': '86FM5FM8+2H'},
#    'price_level': 1,
#    'rating': 4.2,
#    'reference': 'ChIJIdd9mdNmbIgR0jZqHfrikTc',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 600,
#    'vicinity': '1720 N Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1639983, 'lng': -86.55210749999999},
#     'viewport': {'northeast': {'lat': 39.16539932989271,
#       'lng': -86.55060822010728},
#      'southwest': {'lat': 39.16269967010727, 'lng': -86.55330787989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': '3 Amigos Taqueria',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1125,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103251308597211758273">A Google User</a>'],
#      'photo_reference': 'AcYSjRi4PV_FV6Z76GUcjqozM9c5viht8ggUBzCsBwefhtIN_xAaLRdTPXVHooaPbu4vmVlSwaimGHMVpXuF7_c_rs5CJjeNpJxCVuB_X2VjI0vx0JZ96z2Ho7rY0lGJogjQ22Zak6siMl-4d6qTOPVshoR7opX01AclQSsKZIua5uU7E4tF',
#      'width': 900}],
#    'place_id': 'ChIJ_-DNgbFnbIgRyIABZ82LxGs',
#    'plus_code': {'compound_code': '5C7X+H5 Bloomington, Indiana',
#     'global_code': '86FM5C7X+H5'},
#    'price_level': 1,
#    'rating': 4.3,
#    'reference': 'ChIJ_-DNgbFnbIgRyIABZ82LxGs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 96,
#    'vicinity': '340 S Patterson Dr STE 2101, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1640197, 'lng': -86.5166309},
#     'viewport': {'northeast': {'lat': 39.16536492989272,
#       'lng': -86.51518647010728},
#      'southwest': {'lat': 39.16266527010728, 'lng': -86.51788612989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'La Poblana Taco Truck',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110549113624128246183">Bradley Patitz</a>'],
#      'photo_reference': 'AcYSjRjr9XTLGTmnVs15kOwKetq_qF9PFlfy7yJUHw1wu-gLldINoIlLDIxTjvV0mWoQFcx4VAphYJRlAGBw23rEPcaSx-DMlYael7Tr7W2s1SeylVezy2xN7nZyF1WDjgmXoH3bEWPuYTMKPf26C-k10lsWtKEO4-SRNx3A_RqlC6J900U2',
#      'width': 3024}],
#    'place_id': 'ChIJAQAAAONmbIgRZ-xnpi-ziDo',
#    'plus_code': {'compound_code': '5F7M+J8 Bloomington, Indiana',
#     'global_code': '86FM5F7M+J8'},
#    'rating': 4.1,
#    'reference': 'ChIJAQAAAONmbIgRZ-xnpi-ziDo',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': '1320 E 3rd St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.165704, 'lng': -86.52709899999999},
#     'viewport': {'northeast': {'lat': 39.16697312989272,
#       'lng': -86.52576507010727},
#      'southwest': {'lat': 39.16427347010728, 'lng': -86.52846472989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'QDOBA Mexican Eats',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115478436263947727833">Qdoba Mexican Grill</a>'],
#      'photo_reference': 'AcYSjRiHaiYPpq9_tl7WtL_TsFaVS5oHzLewniOA6tipTSvMDqBGhgTdqk3gzDyqVw2uLu7pAh7VF2R1fmrj1iWJ2ubtq6GAIq7BYUAUom0pg5ZRc8fGeWGwi6cB3Cibbf5y0huu9yYBAsXod4lnDDn5p8VAItEtRdTTtzvp_ziCKCbXVKGH',
#      'width': 5000}],
#    'place_id': 'ChIJr6mkZ8JmbIgRnDKxAWikkPw',
#    'plus_code': {'compound_code': '5F8F+75 Bloomington, Indiana',
#     'global_code': '86FM5F8F+75'},
#    'price_level': 1,
#    'rating': 4.4,
#    'reference': 'ChIJr6mkZ8JmbIgRnDKxAWikkPw',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 300,
#    'vicinity': '116 S Indiana Ave Suite 200, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1662857, 'lng': -86.52904219999999},
#     'viewport': {'northeast': {'lat': 39.16769057989272,
#       'lng': -86.52773297010727},
#      'southwest': {'lat': 39.16499092010727, 'lng': -86.53043262989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Chipotle Mexican Grill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100889920549088365838">Anirudh Pillai</a>'],
#      'photo_reference': 'AcYSjRiiH-0MqTzC9ZxplI6qEO1gKWnQ2JH0DsxKSUrfRXsfpUIXGMZ8KDgA8FuV9UTUdgkPpSp1AxX_9szMoZc6Iwoej8s3uRy7tE9KInKHW9414E86Cpv80uEdLeUy-_Xl2Jlfeo5DvhUjAwMmMrF2pnIxI1MJHYSo2QQeeowtEJhoC5Q',
#      'width': 1920}],
#    'place_id': 'ChIJezXRt8JmbIgRx8hhzxhAgms',
#    'plus_code': {'compound_code': '5F8C+G9 Bloomington, Indiana',
#     'global_code': '86FM5F8C+G9'},
#    'price_level': 1,
#    'rating': 3.8,
#    'reference': 'ChIJezXRt8JmbIgRx8hhzxhAgms',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 539,
#    'vicinity': '420 E Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1820139, 'lng': -86.5362439},
#     'viewport': {'northeast': {'lat': 39.18340527989272,
#       'lng': -86.5347660701073},
#      'southwest': {'lat': 39.18070562010728, 'lng': -86.53746572989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': 'La Bonita Restaurant & Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109957459854349032297">Angie Alvarez</a>'],
#      'photo_reference': 'AcYSjRixqiHpsoNSkrYhoc5_moSIjS1DdC2PeAw0USUK5egcXvb0hvGJXgEypjuf6jFeKWmvOm2KDoDuC9TpjZKJTcTBo9EGhXTGBZK0wXSx6-_tc2TkTfY8HwK1g-mb6Z5DV3ZpEp8kzBwJgzN83cqYk8GRLsIc7xPcL-S7jTMtN-tJ8rNm',
#      'width': 3120}],
#    'place_id': 'ChIJEWvT-9NmbIgRVbIw_tzgCMw',
#    'plus_code': {'compound_code': '5FJ7+RG Bloomington, Indiana',
#     'global_code': '86FM5FJ7+RG'},
#    'rating': 4.1,
#    'reference': 'ChIJEWvT-9NmbIgRVbIw_tzgCMw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 219,
#    'vicinity': '1709 N College Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1820129, 'lng': -86.5361604},
#     'viewport': {'northeast': {'lat': 39.18340527989272,
#       'lng': -86.53476182010728},
#      'southwest': {'lat': 39.18070562010728, 'lng': -86.53746147989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Panadería y Pastelería Lupita',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113064244031956905891">A Google User</a>'],
#      'photo_reference': 'AcYSjRgPg4UsxEZ5g-MyXIpYshANHowDgOgNABDnW0V5VkgzvG_mWaXqZppZMTg5lWbfwXG7241ng078bTaFptHR2g8Bejx2tN04ER23ZXMnJ_PTJVYW4I5EPigjbh9yjWOkg-n8Gai3aqfgZf5uHLycJ6rjd9z2COLiRr_wUotzAylPEcqm',
#      'width': 1080}],
#    'place_id': 'ChIJD8l40A9nbIgR5L69Nbh24aI',
#    'plus_code': {'compound_code': '5FJ7+RG Bloomington, Indiana',
#     'global_code': '86FM5FJ7+RG'},
#    'rating': 4.5,
#    'reference': 'ChIJD8l40A9nbIgR5L69Nbh24aI',
#    'scope': 'GOOGLE',
#    'types': ['bakery',
#     'store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 40,
#    'vicinity': '1709 N College Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1693026, 'lng': -86.53316319999999},
#     'viewport': {'northeast': {'lat': 39.17065417989272,
#       'lng': -86.53201962010728},
#      'southwest': {'lat': 39.16795452010728, 'lng': -86.53471927989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Kalao Restaurant/Rum Bar & Night Club',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3072,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105400922442602317530">Michael Burton</a>'],
#      'photo_reference': 'AcYSjRiONYPt6s30HekXSOw0JGhhnxNdhXP5jwiJGkfGN6wolrpWgUvA9h1bwx_r-sYKmTQbIBkwyWJCsMav43Jx9no7X8kG7laGSFqnwtb0zVdbNf3oc8LhET4RcOiJzkIR2W7PAPQEo_OIyQ3UOIDs8akchDtDoqlkSy9nlDHk18KSzZXu',
#      'width': 4080}],
#    'place_id': 'ChIJ49AiAFRnbIgRLEIUkcl3CH4',
#    'plus_code': {'compound_code': '5F98+PP Bloomington, Indiana',
#     'global_code': '86FM5F98+PP'},
#    'rating': 4,
#    'reference': 'ChIJ49AiAFRnbIgRLEIUkcl3CH4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 59,
#    'vicinity': '320 N Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1689804, 'lng': -86.53403139999999},
#     'viewport': {'northeast': {'lat': 39.17026977989271,
#       'lng': -86.53265202010728},
#      'southwest': {'lat': 39.16757012010727, 'lng': -86.53535167989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Taco Bell',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100418446568341950728">Taco Bell</a>'],
#      'photo_reference': 'AcYSjRhoqAkZxNG1LtU9NBPw6vtxpp-VD14MVcCdPyJflG2f8-avmPL-IvckGEDyHXOirfpEQWfEb8EDYkJfqWvhGYYHIJ4KBFndElmAwgvyi2g3b032OM6rdVe_cObxNiLD1j6ZSq5TtzPcoKRi0lspHaUhWi0kaB764wBDYs4HnMW-xay_',
#      'width': 600}],
#    'place_id': 'ChIJCysUR9xmbIgR-6gDsICRwO4',
#    'plus_code': {'compound_code': '5F98+H9 Bloomington, Indiana',
#     'global_code': '86FM5F98+H9'},
#    'price_level': 1,
#    'rating': 3.3,
#    'reference': 'ChIJCysUR9xmbIgR-6gDsICRwO4',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 765,
#    'vicinity': '309 N Walnut St, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1662875, 'lng': -86.53276869999999},
#     'viewport': {'northeast': {'lat': 39.16778422989272,
#       'lng': -86.53141477010728},
#      'southwest': {'lat': 39.16508457010728, 'lng': -86.53411442989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Chubbies Diner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116489615664914648813">A Google User</a>'],
#      'photo_reference': 'AcYSjRjFoAAkLWmLEiJTR-6aBHOiuJp01hoZKoanK6_YmgYm6QKDzLuRbBdCHke3silZ6QBC9DyAcemO_3Vew-SRCC157MqhaQsWsVXVMEpJ2hDaRxQFdtGjG-8ycY_9TQ5DAe4ES5tvKB4VGU6Dq45KS7bsj8slfjUjKGowk-ivNLms73WY',
#      'width': 3024}],
#    'place_id': 'ChIJEwoChXlnbIgRMMHAZKZBTLw',
#    'plus_code': {'compound_code': '5F88+GV Bloomington, Indiana',
#     'global_code': '86FM5F88+GV'},
#    'rating': 4.2,
#    'reference': 'ChIJEwoChXlnbIgRMMHAZKZBTLw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': '118 E Kirkwood Ave, Bloomington'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.1668794, 'lng': -86.53569949999999},
#     'viewport': {'northeast': {'lat': 39.16808332989272,
#       'lng': -86.53434407010728},
#      'southwest': {'lat': 39.16538367010728, 'lng': -86.53704372989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Crazy Horse',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116219341462927373273">Cheryl Luttenegger</a>'],
#      'photo_reference': 'AcYSjRi5P7pce7EkdgfIxQEd3sNXIQa-opTSwJvuXHtDKoKUPzt6uKvDxqtfwcJ4av0ccULJpvzXSs2VWIH3-wdFe9QZTk0lN1Dul5fz83_JazAVrAOtPwiTubUUGQ1bba8uJHPGcF7wMs0RdpG4MwzpmWsVMIGrZfln96vL8-AUpPYc-dkq',
#      'width': 4032}],
#    'place_id': 'ChIJP0KRCt5mbIgRtvuN4ZtPrHs',
#    'plus_code': {'compound_code': '5F87+QP Bloomington, Indiana',
#     'global_code': '86FM5F87+QP'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJP0KRCt5mbIgRtvuN4ZtPrHs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 591,
#    'vicinity': '214 W Kirkwood Ave, Bloomington'}],
#  'status': 'OK'}

# %%
data
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': 39.1595449, 'lng': -86.53...
# 1      OPERATIONAL  {'location': {'lat': 39.1689804, 'lng': -86.53...
# 2      OPERATIONAL  {'location': {'lat': 39.1611023, 'lng': -86.53...
# 3      OPERATIONAL  {'location': {'lat': 39.1666851, 'lng': -86.52...
# 4      OPERATIONAL  {'location': {'lat': 39.1654941, 'lng': -86.55...
# 5      OPERATIONAL  {'location': {'lat': 39.1600089, 'lng': -86.53...
# 6      OPERATIONAL  {'location': {'lat': 39.166235, 'lng': -86.528...
# 7      OPERATIONAL  {'location': {'lat': 39.1662505, 'lng': -86.52...
# 8      OPERATIONAL  {'location': {'lat': 39.165704, 'lng': -86.527...
# 9      OPERATIONAL  {'location': {'lat': 39.1662857, 'lng': -86.52...
# 10     OPERATIONAL  {'location': {'lat': 39.1667031, 'lng': -86.52...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                               name        opening_hours  \
# 0                          Rally's   {'open_now': True}
# 1                        Taco Bell   {'open_now': True}
# 2                          Wendy's  {'open_now': False}
# 3                        Five Guys  {'open_now': False}
# 4              Hinkle's Hamburgers  {'open_now': False}
# 5                           Arby's  {'open_now': False}
# 6                     Jimmy John's   {'open_now': True}
# 7   Raising Cane's Chicken Fingers  {'open_now': False}
# 8               QDOBA Mexican Eats  {'open_now': False}
# 9           Chipotle Mexican Grill  {'open_now': False}
# 10                        Potbelly  {'open_now': False}
#
#                                                photos  \
# 0   [{'height': 1440, 'html_attributions': ['<a hr...
# 1   [{'height': 600, 'html_attributions': ['<a hre...
# 2   [{'height': 720, 'html_attributions': ['<a hre...
# 3   [{'height': 2268, 'html_attributions': ['<a hr...
# 4   [{'height': 1080, 'html_attributions': ['<a hr...
# 5   [{'height': 583, 'html_attributions': ['<a hre...
# 6   [{'height': 1920, 'html_attributions': ['<a hr...
# 7   [{'height': 1500, 'html_attributions': ['<a hr...
# 8   [{'height': 5000, 'html_attributions': ['<a hr...
# 9   [{'height': 1080, 'html_attributions': ['<a hr...
# 10  [{'height': 900, 'html_attributions': ['<a hre...
#
#                        place_id  \
# 0   ChIJi8WMIeRmbIgR-5qohDUhCog
# 1   ChIJCysUR9xmbIgR-6gDsICRwO4
# 2   ChIJp0mrS-FmbIgRoxS6RrUXhVQ
# 3   ChIJRXyDRNpnbIgRQs5YClpXTNw
# 4   ChIJu-YruRdnbIgRBBsNsPkwdmo
# 5   ChIJocv9JuRmbIgRv_zjdhxboNE
# 6   ChIJYcKwlMJmbIgRYr6LY-zNcy4
# 7   ChIJF9HqlpdnbIgRLYto2yJ-g1k
# 8   ChIJr6mkZ8JmbIgRnDKxAWikkPw
# 9   ChIJezXRt8JmbIgRx8hhzxhAgms
# 10  ChIJ97ej9cJmbIgRLOQGfM8QaWg
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': '5F58+R9 Bloomington, Indian...            1     4.0
# 1   {'compound_code': '5F98+H9 Bloomington, Indian...            1     3.3
# 2   {'compound_code': '5F67+CM Bloomington, Indian...            1     3.9
# 3   {'compound_code': '5F8C+PH Bloomington, Indian...            2     4.3
# 4   {'compound_code': '5C8X+5P Bloomington, Indian...            1     4.6
# 5   {'compound_code': '5F68+2M Bloomington, Indian...            1     3.9
# 6   {'compound_code': '5F8C+FH Bloomington, Indian...            1     3.5
# 7   {'compound_code': '5F8C+GF Bloomington, Indian...            1     3.3
# 8   {'compound_code': '5F8F+75 Bloomington, Indian...            1     4.4
# 9   {'compound_code': '5F8C+G9 Bloomington, Indian...            1     3.8
# 10  {'compound_code': '5F8C+MX Bloomington, Indian...            1     4.4
#
#                       reference   scope  \
# 0   ChIJi8WMIeRmbIgR-5qohDUhCog  GOOGLE
# 1   ChIJCysUR9xmbIgR-6gDsICRwO4  GOOGLE
# 2   ChIJp0mrS-FmbIgRoxS6RrUXhVQ  GOOGLE
# 3   ChIJRXyDRNpnbIgRQs5YClpXTNw  GOOGLE
# 4   ChIJu-YruRdnbIgRBBsNsPkwdmo  GOOGLE
# 5   ChIJocv9JuRmbIgRv_zjdhxboNE  GOOGLE
# 6   ChIJYcKwlMJmbIgRYr6LY-zNcy4  GOOGLE
# 7   ChIJF9HqlpdnbIgRLYto2yJ-g1k  GOOGLE
# 8   ChIJr6mkZ8JmbIgRnDKxAWikkPw  GOOGLE
# 9   ChIJezXRt8JmbIgRx8hhzxhAgms  GOOGLE
# 10  ChIJ97ej9cJmbIgRLOQGfM8QaWg  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [restaurant, food, point_of_interest, establis...                1034
# 1   [meal_takeaway, restaurant, food, point_of_int...                 765
# 2   [restaurant, food, point_of_interest, establis...                 828
# 3   [meal_takeaway, restaurant, food, point_of_int...                 197
# 4   [restaurant, food, point_of_interest, establis...                 673
# 5   [meal_takeaway, restaurant, food, store, point...                 400
# 6   [meal_delivery, meal_takeaway, restaurant, foo...                 121
# 7   [restaurant, food, point_of_interest, establis...                  39
# 8   [bar, restaurant, food, point_of_interest, est...                 300
# 9   [restaurant, food, point_of_interest, establis...                 539
# 10  [restaurant, food, point_of_interest, establis...                 123
#
#                                     vicinity
# 0               550 S Walnut St, Bloomington
# 1               309 N Walnut St, Bloomington
# 2                  221 W 2nd St, Bloomington
# 3            425 E Kirkwood Ave, Bloomington
# 4                206 S Adams St, Bloomington
# 5               535 S Walnut St, Bloomington
# 6            430 E Kirkwood Ave, Bloomington
# 7            422 E Kirkwood Ave, Bloomington
# 8   116 S Indiana Ave Suite 200, Bloomington
# 9            420 E Kirkwood Ave, Bloomington
# 10           517 E Kirkwood Ave, Bloomington

# %%
data[['name', 'price_level', 'rating', 'types',
       'user_ratings_total', 'vicinity']].to_csv('data.csv')
